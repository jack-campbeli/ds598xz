# %%
# !pip install git+https://github.com/glmcdona/LuxPythonEnvGym.git
# !pip install kaggle-environments -U
# Out:
# DEPRECATION: Loading egg at /projectnb/ds598xz/students/jawicamp/.venv/lib/python3.11/site-packages/luxai2021-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting git+https://github.com/glmcdona/LuxPythonEnvGym.git
#   Cloning https://github.com/glmcdona/LuxPythonEnvGym.git to /scratch/6756892.1.academic-gpu/pip-req-build-e6aeueo4
#   Running command git clone --filter=blob:none --quiet https://github.com/glmcdona/LuxPythonEnvGym.git /scratch/6756892.1.academic-gpu/pip-req-build-e6aeueo4
#   Resolved https://github.com/glmcdona/LuxPythonEnvGym.git to commit 55e8ddc15012fd55f17b23aa2e73c919467e43e3
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting pytest (from luxai2021==0.1.0)
#   Downloading pytest-8.1.1-py3-none-any.whl.metadata (7.6 kB)
# Collecting stable-baselines3==1.2.1a2 (from luxai2021==0.1.0)
#   Downloading stable_baselines3-1.2.1a2-py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: numpy in /projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages (from luxai2021==0.1.0) (1.26.4)
# Collecting tensorboard (from luxai2021==0.1.0)
#   Downloading tensorboard-2.16.2-py3-none-any.whl.metadata (1.6 kB)
# Collecting gym==0.19.0 (from luxai2021==0.1.0)
#   Downloading gym-0.19.0.tar.gz (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 28.4 MB/s eta 0:00:00a 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [1 lines of output]
#       error in gym setup command: 'extras_require' must be a dictionary whose values are strings or lists of strings containing valid project/version requirement specifiers.
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# DEPRECATION: Loading egg at /projectnb/ds598xz/students/jawicamp/.venv/lib/python3.11/site-packages/luxai2021-0.1.0-py3.11.egg is deprecated. pip 24.3 will enforce this behaviour change. A possible replacement is to use pip for package installation.. Discussion can be found at https://github.com/pypa/pip/issues/12330
# Collecting kaggle-environments
#   Downloading kaggle_environments-1.14.3-py2.py3-none-any.whl.metadata (10 kB)
# Collecting Flask>=1.1.2 (from kaggle-environments)
#   Downloading flask-3.0.3-py3-none-any.whl.metadata (3.2 kB)
# Collecting gymnasium==0.29.0 (from kaggle-environments)
#   Downloading gymnasium-0.29.0-py3-none-any.whl.metadata (10 kB)
# Collecting jsonschema>=3.0.1 (from kaggle-environments)
#   Downloading jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: numpy>=1.19.5 in /projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages (from kaggle-environments) (1.26.4)
# Collecting pettingzoo==1.24.0 (from kaggle-environments)
#   Downloading pettingzoo-1.24.0-py3-none-any.whl.metadata (8.1 kB)
# Collecting requests>=2.25.1 (from kaggle-environments)
#   Downloading requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Requirement already satisfied: scipy>=1.11.2 in /projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages (from kaggle-environments) (1.13.0)
# Collecting shimmy>=1.2.1 (from kaggle-environments)
#   Downloading Shimmy-1.3.0-py3-none-any.whl.metadata (3.7 kB)
# Collecting stable-baselines3==2.1.0 (from kaggle-environments)
#   Downloading stable_baselines3-2.1.0-py3-none-any.whl.metadata (5.2 kB)
# Collecting transformers>=4.33.1 (from kaggle-environments)
#   Downloading transformers-4.40.0-py3-none-any.whl.metadata (137 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.6/137.6 kB 6.4 MB/s eta 0:00:00
# Collecting vec-noise>=1.1.4 (from kaggle-environments)
#   Downloading vec_noise-1.1.4.zip (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.1/134.1 kB 23.3 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Installing backend dependencies ... done
#   Preparing metadata (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Preparing metadata (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [60 lines of output]
#       running dist_info
#       creating /scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info
#       writing /scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info/PKG-INFO
#       writing dependency_links to /scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info/dependency_links.txt
#       writing requirements to /scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info/requires.txt
#       writing top-level names to /scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info/top_level.txt
#       writing manifest file '/scratch/6756892.1.academic-gpu/pip-modern-metadata-gk369ggk/vec_noise.egg-info/SOURCES.txt'
#       Traceback (most recent call last):
#         File "/projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#         File "/projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/projectnb/ds598xz/students/jawicamp/.venv/lib64/python3.11/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 149, in prepare_metadata_for_build_wheel
#           return hook(metadata_directory, config_settings)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 366, in prepare_metadata_for_build_wheel
#           self.run_setup()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 487, in run_setup
#           super().run_setup(setup_script=setup_script)
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/build_meta.py", line 311, in run_setup
#           exec(code, locals())
#         File "<string>", line 20, in <module>
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/__init__.py", line 104, in setup
#           return distutils.core.setup(**attrs)
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 184, in setup
#           return run_commands(dist)
#                  ^^^^^^^^^^^^^^^^^^
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/core.py", line 200, in run_commands
#           dist.run_commands()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 969, in run_commands
#           self.run_command(cmd)
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/dist.py", line 967, in run_command
#           super().run_command(command)
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/dist.py", line 988, in run_command
#           cmd_obj.run()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/dist_info.py", line 92, in run
#           self.egg_info.run()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 321, in run
#           self.find_sources()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 329, in find_sources
#           mm.run()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 550, in run
#           self.add_defaults()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/egg_info.py", line 588, in add_defaults
#           sdist.add_defaults(self)
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/command/sdist.py", line 102, in add_defaults
#           super().add_defaults()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 250, in add_defaults
#           self._add_defaults_ext()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/command/sdist.py", line 334, in _add_defaults_ext
#           build_ext = self.get_finalized_command('build_ext')
#                       ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 303, in get_finalized_command
#           cmd_obj.ensure_finalized()
#         File "/scratch/6756892.1.academic-gpu/pip-build-env-mh88bk_n/overlay/lib/python3.11/site-packages/setuptools/_distutils/cmd.py", line 111, in ensure_finalized
#           self.finalize_options()
#         File "<string>", line 10, in finalize_options
#       AttributeError: 'dict' object has no attribute '__NUMPY_SETUP__'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: metadata-generation-failed
#
# × Encountered error while generating package metadata.
# ╰─> See above for output.
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for details.

# %% [markdown]
# # Beat the Midterm Champion
#
# This is a notebook uses the Kaggle Lux AI environment to run your agent and the Midterm Champion in a game. Your agent is represented by Player 0. Midterm Champion is represented as Player 1.
#
# To Run, unzip your model from your kaggle submission zip file in the same folder as this notebook. So that your folder structure looks like this:
#
#     v HW4
#     |-- HW4.ipynb
#     |-- UNet_attention >
#     |--v my_agent >
#     |--|-- main.py
#
#
# Replace the first entry in agent variable in the next code section to point to the main.py of your submission code.
#
# Run for a 100 episodes and show that you win more than 50 of such episodes.

# %%
from kaggle_environments import make, evaluate
import numpy as np

environment = "lux_ai_2021"
steps = []

# Which agents to run repeatedly.  Same as env.run(agents)
agents = ["../Agent_share/main.py" , "./UNet_attention/main.py"]
#          ---------------------------- <- replace the underlined section with path to your agent  
    
# How many times to run them.
num_episodes = 100

rewards = [[] for i in range(num_episodes)]
envs = [[] for i in range(num_episodes)]
wins = [[] for i in range(num_episodes)]
for i in range(num_episodes):
  configuration = {"seed": i, "loglevel": 2, "annotations": True}
  envs[i] = make(environment, configuration, steps, debug=False)
  last_state = envs[i].run(agents)[-1]
  rewards[i] = [state.reward if state.reward is not None else 0 for state in last_state]

wins = np.argmax(rewards, axis=1)
games_won = np.count_nonzero(wins == 0)
print(f'Number of games won by your agent: {games_won}')
print('Pass' if games_won > (0.5 * num_episodes) else 'Fail')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> from kaggle_environments import make, evaluate
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> import numpy as np
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> environment = "lux_ai_2021"
#
# ModuleNotFoundError: No module named 'kaggle_environments'

# %%
# Render any specific match
# Use this for debugging or getting more insight for training
# Select a match
matchId = 0

env = envs[matchId]
env.render(mode="ipython", width=1200, height=800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb Cell 4 line 6
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> # Render any specific match
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=1'>2</a> # Use this for debugging or getting more insight for training
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> # Select a match
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> matchId = 0
# ----> <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> env = envs[matchId]
#       <a href='vscode-notebook-cell://scc-ondemand2.bu.edu/projectnb/ds598xz/students/jawicamp/HW4/HW4.ipynb#W3sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a> env.render(mode="ipython", width=1200, height=800)
#
# NameError: name 'envs' is not defined
